# %%
# !pip install python-docx

# %%
# importing necessary libraries 

import os
import re
import PyPDF2
import docx

# Define your dictionary of state districts and village names
location_dictionary = {
    'Angul': {
        'Capital': 'Angul',
        'Towns': ['Talcher', 'Athmallik'],
        'Villages': ['Kaniha', 'Chhendipada', 'Kishorenagar']
    },
    'Balangir': {
        'Capital': 'Balangir',
        'Towns': ['Titlagarh', 'Patnagarh'],
        'Villages': ['Belpada', 'Loisingha', 'Tureikela']
    },
    'Balasore': {
        'Capital': 'Balasore',
        'Towns': ['Baleshwar', 'Nilagiri'],
        'Villages': ['Soro', 'Remuna', 'Basta']
    },
    

    'Bargarh': {
        'Capital': 'Bargarh',
        'Towns': ['Padampur', 'Bhatli'],
        'Villages': ['Sohela', 'Ambabhona', 'Barpali']
    },
    'Bhadrak': {
        'Capital': 'Bhadrak',
        'Towns': ['Basudebpur', 'Dhamanagar'],
        'Villages': ['Bonth', 'Chandbali', 'Dhusuri']
    },
    'Cuttack': {
        'Capital': 'Cuttack',
        'Towns': ['Bhubaneshwar', 'Choudwar'],
        'Villages': ['Barang', 'Banki', 'Athagarh']
    },
    'Deogarh': {
        'Capital': 'Deogarh',
        'Towns': ['Barkote', 'Reamal'],
        'Villages': ['Tileibani', 'Riamal', 'Baliamba']
    },
    'Dhenkanal': {
        'Capital': 'Dhenkanal',
        'Towns': ['Kamakshyanagar', 'Bhuban'],
        'Villages': ['Hindol', 'Parajang', 'Gondia']
    },
    'Gajapati': {
        'Capital': 'Paralakhemundi',
        'Towns': ['Paralakhemundi', 'R.Udaygiri'],
        'Villages': ['Mohana', 'Kasinagar', 'Gumma']
    },
    'Ganjam': {
        'Capital': 'Chhatrapur',
        'Towns': ['Berhampur', 'Brahmapur'],
        'Villages': ['Asika', 'Buguda', 'Gopalpur']
    },
    'Jagatsinghpur': {
        'Capital': 'Jagatsinghpur',
        'Towns': ['Paradip', 'Tirtol'],
        'Villages': ['Raghunathpur', 'Balikuda', 'Kujang']
    },
    'Jajpur': {
        'Capital': 'Jajpur',
        'Towns': ['Jajpur Road', 'Dharmasala'],
        'Villages': ['Kuakhia', 'Binjharpur', 'Danagadi']
    },
    'Jharsuguda': {
        'Capital': 'Jharsuguda',
        'Towns': ['Brajarajnagar', 'Jharsuguda'],
        'Villages': ['Laikera', 'Kirmira', 'Badmal']
    },
    'Kalahandi': {
        'Capital': 'Bhawanipatna',
        'Towns': ['Bhawanipatna', 'Junagarh'],
        'Villages': ['Dharamgarh', 'Kesinga', 'Koksara']
    },
    'Kandhamal': {
        'Capital': 'Phulbani',
        'Towns': ['Phulbani', 'G.Udayagiri'],
        'Villages': ['Baliguda', 'Tikabali', 'Raikia']
    },
    'Kendrapara': {
        'Capital': 'Kendrapara',
        'Towns': ['Kendrapara', 'Pattamundai'],
        'Villages': ['Aul', 'Rajnagar', 'Derabish']
    },
    'Kendujhar': {
        'Capital': 'Kendujhar',
        'Towns': ['Anandapur', 'Joda'],
        'Villages': ['Barbil', 'Champua', 'Ghasipura']
    },
    'Khordha': {
        'Capital': 'Khordha',
        'Towns': ['Jatni', 'Khordha'],
        'Villages': ['Balugaon', 'Banapur', 'Begunia']
    },
    'Koraput': {
        'Capital': 'Jeypore',
        'Towns': ['Jeypore', 'Kotpad'],
        'Villages': ['Sunabeda', 'Semiliguda', 'Koraput']
    },
    'Malkangiri': {
        'Capital': 'Malkangiri',
        'Towns': ['Motu', 'Jeypore'],
        'Villages': ['Chitrakonda', 'Mathili', 'Kudumulgumma']
    },
    'Mayurbhanj': {
        'Capital': 'Baripada',
        'Towns': ['Baripada', 'Rairangpur'],
        'Villages': ['Betanati', 'Kaptipada', 'Shuliapada']
    },
    'Nabarangpur': {
        'Capital': 'Nabarangpur',
        'Towns': ['Nabarangpur', 'Umarkote'],
        'Villages': ['Jharigam', 'Papadahandi', 'Kodinga']
    },
    'Nayagarh': {
        'Capital': 'Nayagarh',
        'Towns': ['Nayagarh', 'Khandapada'],
        'Villages': ['Ranapur', 'Sarankul', 'Odagaon']
    },
    'Nuapada': {
        'Capital': 'Nuapada',
        'Towns': ['Nuapada', 'Khariar'],
        'Villages': ['Sinapali', 'Komna', 'Boden']
    },
    'Puri': {
        'Capital': 'Puri',
        'Towns': ['Konark', 'Nimapada'],
        'Villages': ['Pipili', 'Delanga', 'Satyabadi']
    },
    'Rayagada': {
        'Capital': 'Rayagada',
        'Towns': ['Rayagada', 'Gunupur'],
        'Villages': ['Gudari', 'Kashipur', 'Bissam Cuttack']
    },
    'Sambalpur': {
        'Capital': 'Sambalpur',
        'Towns': ['Burla', 'Hirakud'],
        'Villages': ['Jharsuguda', 'Rengali', 'Kuchinda']
    },
    'Subarnapur': {
        'Capital': 'Sonepur',
        'Towns': ['Sonepur', 'Binka'],
        'Villages': ['Tarbha', 'Ullunda', 'Dunguripali']
    },
    'Sundargarh': {
        'Capital': 'Sundargarh',
        'Towns': ['Rourkela', 'Biramitrapur'],
        'Villages': ['Hemgir', 'Lathikata', 'Kuanrmunda']
    },
     "Ajmer": {
        "Capital": "Ajmer",
        "Small Towns": ["Kishangarh", "Beawar", "Nasirabad"],
        "Villages": ["Pushkar", "Kekri", "Sarwar"]
    },
    "Alwar": {
        "Capital": "Alwar",
        "Small Towns": ["Bhiwadi", "Khairthal", "Tijara"],
        "Villages": ["Neemrana", "Rajgarh", "Thanagazi"]
    },
    "Banswara": {
        "Capital": "Banswara",
        "Small Towns": ["Kushalgarh", "Partapur", "Bagidora"],
        "Villages": ["Ghatol", "Talwara", "Sajjangarh"]
    },
    "Baran": {
        "Capital": "Baran",
        "Small Towns": ["Anta", "Atru", "Chhabra"],
        "Villages": ["Kishanganj", "Shahabad", "Mangrol"]
    },
    "Barmer": {
        "Capital": "Barmer",
        "Small Towns": ["Balotra", "Siwana", "Sheo"],
        "Villages": ["Dhorimanna", "Baytoo", "Guda Malani"]
    },
    "Bharatpur": {
        "Capital": "Bharatpur",
        "Small Towns": ["Deeg", "Kaman", "Nagar"],
        "Villages": ["Kumher", "Nadbai", "Weir"]
    },
    "Bhilwara": {
        "Capital": "Bhilwara",
        "Small Towns": ["Mandal", "Asind", "Shahpura"],
        "Villages": ["Mandalgarh", "Beejoliya", "Gulabpura"]
    },
    "Bikaner": {
        "Capital": "Bikaner",
        "Small Towns": ["Nokha", "Sri Dungargarh", "Lunkaransar"],
        "Villages": ["Kolayat", "Deshnoke", "Khajuwala"]
    },
    "Bundi": {
        "Capital": "Bundi",
        "Small Towns": ["Keshoraipatan", "Nainwa", "Indragarh"],
        "Villages": ["Talera", "Lakheri", "Kota"]
    },
    "Chittorgarh": {
        "Capital": "Chittorgarh",
        "Small Towns": ["Nimbahera", "Bari Sadri", "Kapasan"],
        "Villages": ["Bhadesar", "Pratapgarh", "Chhoti Sadri"]
    },
    "Churu": {
        "Capital": "Churu",
        "Small Towns": ["Rajgarh", "Ratangarh", "Sardarshahar"],
        "Villages": ["Taranagar", "Rajaldesar", "Sujangarh"]
    },
    "Dausa": {
        "Capital": "Dausa",
        "Small Towns": ["Bandikui", "Lalsot", "Mahwa"],
        "Villages": ["Sikrai", "Baswa", "Mehandipur"]
    },
    "Dholpur": {
        "Capital": "Dholpur",
        "Small Towns": ["Bari", "Rajakhera", "Sarmathura"],
        "Villages": ["Baseri", "Dhaulpur", "Sepau"]
    },
    "Dungarpur": {
        "Capital": "Dungarpur",
        "Small Towns": ["Sagwara", "Aspur", "Simalwara"],
        "Villages": ["Galiakot", "Bichiwara", "Chawand"]
    },
    "Hanumangarh": {
        "Capital": "Hanumangarh",
        "Small Towns": ["Pilibanga", "Sangaria", "Nohar"],
        "Villages": ["Rawatsar", "Bhadra", "Tibbi"]
    },
    "Jaipur": {
        "Capital": "Jaipur",
        "Small Towns": ["Sanganer", "Chaksu", "Phulera"],
        "Villages": ["Amber", "Bassi", "Kanota"]
    },
    "Jaisalmer": {
        "Capital": "Jaisalmer",
        "Small Towns": ["Pokaran", "Fatehgarh", "Nachna"],
        "Villages": ["Sam", "Devi", "Khuiyala"]
    },
    "Jalore": {
        "Capital": "Jalore",
        "Small Towns": ["Bhinmal", "Sanchore", "Ahore"],
        "Villages": ["Jaswantpura", "Bagra", "Bhadrajun"]
    },
    "Jhalawar": {
        "Capital": "Jhalawar",
        "Small Towns": ["Khanpur", "Manohar Thana", "Aklera"],
        "Villages": ["Bakani", "Chhabra", "Pirawa"]
    },
    "Jhunjhunu": {
        "Capital": "Jhunjhunu",
        "Small Towns": ["Udaipurwati", "Pilani", "Nawalgarh"],
        "Villages": ["Khetri", "Chirawa", "Surajgarh"]
    },
    "Jodhpur": {
        "Capital": "Jodhpur",
        "Small Towns": ["Phalodi", "Osian", "Bilara"],
        "Villages": ["Mandore", "Merta", "Nagaur"]
    },
    "Karauli": {
        "Capital": "Karauli",
        "Small Towns": ["Hindaun", "Nadoti", "Sapotra"],
        "Villages": ["Mandrail", "Todabhim", "Sikandra"]
    },
    "Kota": {
        "Capital": "Kota",
        "Small Towns": ["Ramganj Mandi", "Sangod", "Rawatbhata"],
        "Villages": ["Keshoraipatan", "Chechat", "Itawa"]
    },
    "Nagaur": {
        "Capital": "Nagaur",
        "Small Towns": ["Makrana", "Merta City", "Kuchaman City"],
        "Villages": ["Degana", "Ladnun", "Parbatsar"]
    },
    "Pali": {
        "Capital": "Pali",
        "Small Towns": ["Sojat", "Falna", "Bali"],
        "Villages": ["Marwar Junction", "Rani", "Sumerpur"]
    },
    "Pratapgarh": {
        "Capital": "Pratapgarh",
        "Small Towns": ["Chhoti Sadri", "Dhariawad", "Piploda"],
        "Villages": ["Arnod", "Bhinder", "Palojori"]
    },
    "Rajsamand": {
        "Capital": "Rajsamand",
        "Small Towns": ["Nathdwara", "Kumbhalgarh", "Amet"],
        "Villages": ["Bhim", "Devgarh", "Kankroli"]
    },
    "Sawai Madhopur": {
        "Capital": "Sawai Madhopur",
        "Small Towns": ["Gangapur", "Bonli", "Bamanwas"],
        "Villages": ["Lalsot", "Malarna Dungar", "Khandar"]
    },
    "Sikar": {
        "Capital": "Sikar",
        "Small Towns": ["Neem-Ka-Thana", "Fatehpur", "Lachhmangarh"],
        "Villages": ["Danta Ramgarh", "Khandela", "Dhod"]
    },
    "Sirohi": {
        "Capital": "Sirohi",
        "Small Towns": ["Mount Abu", "Pindwara", "Abu Road"],
        "Villages": ["Sheoganj", "Reodar", "Dhanta"]
    },
    "Tonk": {
        "Capital": "Tonk",
        "Small Towns": ["Deoli", "Malpura", "Niwai"],
        "Villages": ["Uniara", "Todaraisingh", "Bonli"]
    },
    "Udaipur": {
        "Capital": "Udaipur",
        "Small Towns": ["Rajsamand", "Salumbar", "Mavli"],
        "Villages": ["Kherwara", "Gogunda", "Jhadol"]
    }

}


# Specify the folder path containing the DOCX files
folder_path = "D:\\first"

# Iterate over all Word files (.docx) in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".docx"):
        file_path = os.path.join(folder_path, file_name)

        # Open the Word file
        doc = docx.Document(file_path)

        # Initialize a variable to keep track of whether a recognizable location is found or not
        location_found = False

        # Iterate over each paragraph in the Word file
        for para in doc.paragraphs:
            text = para.text

            # Extract present locations using regular expressions
            # Modify the regular expression pattern as per your needs
            pattern = r"\b(?:{0})\b".format("|".join(location_dictionary.keys()))
            matches = re.findall(pattern, text, flags=re.IGNORECASE)

            # Display the first matched present location
            if matches and not location_found:
                print("Present location in {0}:".format(file_name))
                print(matches[0])
                print("---")
                location_found = True
# Out:
# Present location in 0_Babasreeta Mishra Resume (1).docx:
# Nabarangpur
# ---
# Present location in Biswaranjan kar  - Branch manager - 10 Yrs 0 Month (1).docx:
# Dungarpur
# ---
# Present location in nirakar sahoo.docx:
# Kendrapara
# ---
# Present location in Rajeev Resume 2023 (2).docx:
# Ajmer
# ---
# Present location in Saroj Mahapatra (2).docx:
# Ganjam
# ---
# Present location in saumitra trpiathy.docx:
# Mayurbhanj
# ---
# Present location in SUMEET KUMAR ROUT_WORK ASSIST (1).docx:
# SAMBALPUR
# ---
# Present location in Work Assist BHAWNAMULCHANDANI (3).docx:
# Jaipur
# ---
# Present location in Work Assist PriyankaGupta (4) (1).docx:
# Jaipur
# ---
# Present location in Work Assist SANJEEVKUMARBANERJEE (3).docx:
# Alwar
# ---
# Present location in Work Assist TusharMathur (1).docx:
# Jaipur
# ---
# Present location in Work Assist_AtulSharma_ KMB_ BM _ Jaipur (3) (1).docx:
# Jaipur
# ---
# Present location in workassist Sanket sharma (2).docx:
# Jaipur
# ---
# ...
